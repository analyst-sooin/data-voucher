# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#
# WARNING: You are using pip version 20.2.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'C:\Users\inthe\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
data = pd.read_excel('수질TMS 1월 data.xlsx', header=None)
data
# Out:
# C:\Users\inthe\AppData\Local\Programs\Python\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                 0           1       2   \
# 0     양주신천하수(1방류구)2021/01/01 00 시 ~ 2021/01/31 23시         NaN     NaN
# 1                                              방류구        측정일자    측정시간
# 2                                              NaN         NaN     NaN
# 3                                                1  2021/01/01  00시00분
# 4                                                1  2021/01/01  00시05분
# ...                                            ...         ...     ...
# 8926                                             1  2021/01/31  23시35분
# 8927                                             1  2021/01/31  23시40분
# 8928                                             1  2021/01/31  23시45분
# ...

# %%
data = data.drop(0)

# %%
data
# Out:
#        0           1       2          3     4     5         6    7     8   \
# 1     방류구        측정일자    측정시간  COD(mg/L)   NaN   NaN  SS(mg/L)  NaN   NaN
# 2     NaN         NaN     NaN        기준치   측정치  상태정보       기준치  측정치  상태정보
# 3       1  2021/01/01  00시00분         40  19.0  장비정상        10  7.2  장비정상
# 4       1  2021/01/01  00시05분         40  19.0  장비정상        10  7.1  장비정상
# 5       1  2021/01/01  00시10분         40  19.0  장비정상        10  6.9  장비정상
# ...   ...         ...     ...        ...   ...   ...       ...  ...   ...
# 8926    1  2021/01/31  23시35분         40  -0.6  장비정상        10  8.7  장비정상
# 8927    1  2021/01/31  23시40분         40  -0.6  장비정상        10  8.7  장비정상
# 8928    1  2021/01/31  23시45분         40  -0.6  장비정상        10  8.6  장비정상
# 8929    1  2021/01/31  23시50분         40  -0.6  장비정상        10  8.5  장비정상
# 8930    1  2021/01/31  23시55분         40  60.9  장비정상        10  8.5  장비정상
#
#              9       10    11         12     13    14     15   16    17
# ...

# %%
columns = ['방류구','측정일자',	'측정시간',	'COD_기준치', 'COD_측정치',	'COD_상태정보',	'SS_기준치',	'SS_측정치',	'SS_상태정보',	'T-N_기준치'	,'T-N_측정치',	'T-N_상태정보',	'T-P_기준치',	'T-P_측정치','T-P_상태정보',	'pH_기준치'	,'PH_측정치', 'PH_상태정보']

data.columns = columns
data
# Out:
#       방류구        측정일자    측정시간    COD_기준치 COD_측정치 COD_상태정보    SS_기준치 SS_측정치  \
# 1     방류구        측정일자    측정시간  COD(mg/L)     NaN      NaN  SS(mg/L)    NaN
# 2     NaN         NaN     NaN        기준치     측정치     상태정보       기준치    측정치
# 3       1  2021/01/01  00시00분         40    19.0     장비정상        10    7.2
# 4       1  2021/01/01  00시05분         40    19.0     장비정상        10    7.1
# 5       1  2021/01/01  00시10분         40    19.0     장비정상        10    6.9
# ...   ...         ...     ...        ...     ...      ...       ...    ...
# 8926    1  2021/01/31  23시35분         40    -0.6     장비정상        10    8.7
# 8927    1  2021/01/31  23시40분         40    -0.6     장비정상        10    8.7
# 8928    1  2021/01/31  23시45분         40    -0.6     장비정상        10    8.6
# 8929    1  2021/01/31  23시50분         40    -0.6     장비정상        10    8.5
# 8930    1  2021/01/31  23시55분         40    60.9     장비정상        10    8.5
#
# ...

# %%
data =data.drop([1,2])
data
# Out:
#      방류구        측정일자    측정시간 COD_기준치 COD_측정치 COD_상태정보 SS_기준치 SS_측정치 SS_상태정보  \
# 3      1  2021/01/01  00시00분      40    19.0     장비정상     10    7.2    장비정상
# 4      1  2021/01/01  00시05분      40    19.0     장비정상     10    7.1    장비정상
# 5      1  2021/01/01  00시10분      40    19.0     장비정상     10    6.9    장비정상
# 6      1  2021/01/01  00시15분      40    19.0     장비정상     10    6.9    장비정상
# 7      1  2021/01/01  00시20분      40    19.0     장비정상     10    6.9    장비정상
# ...   ..         ...     ...     ...     ...      ...    ...    ...     ...
# 8926   1  2021/01/31  23시35분      40    -0.6     장비정상     10    8.7    장비정상
# 8927   1  2021/01/31  23시40분      40    -0.6     장비정상     10    8.7    장비정상
# 8928   1  2021/01/31  23시45분      40    -0.6     장비정상     10    8.6    장비정상
# 8929   1  2021/01/31  23시50분      40    -0.6     장비정상     10    8.5    장비정상
# 8930   1  2021/01/31  23시55분      40    60.9     장비정상     10    8.5    장비정상
#
# ...

# %%
data
# Out:
#      방류구        측정일자    측정시간 COD_기준치 COD_측정치 COD_상태정보 SS_기준치 SS_측정치 SS_상태정보  \
# 3      1  2021/01/01  00시00분      40    19.0     장비정상     10    7.2    장비정상
# 4      1  2021/01/01  00시05분      40    19.0     장비정상     10    7.1    장비정상
# 5      1  2021/01/01  00시10분      40    19.0     장비정상     10    6.9    장비정상
# 6      1  2021/01/01  00시15분      40    19.0     장비정상     10    6.9    장비정상
# 7      1  2021/01/01  00시20분      40    19.0     장비정상     10    6.9    장비정상
# ...   ..         ...     ...     ...     ...      ...    ...    ...     ...
# 8926   1  2021/01/31  23시35분      40    -0.6     장비정상     10    8.7    장비정상
# 8927   1  2021/01/31  23시40분      40    -0.6     장비정상     10    8.7    장비정상
# 8928   1  2021/01/31  23시45분      40    -0.6     장비정상     10    8.6    장비정상
# 8929   1  2021/01/31  23시50분      40    -0.6     장비정상     10    8.5    장비정상
# 8930   1  2021/01/31  23시55분      40    60.9     장비정상     10    8.5    장비정상
#
# ...

# %%
data = data.astype({'SS_측정치':float,'T-N_측정치':float, 'T-P_측정치':float, 'T-N_측정치':float})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8928 entries, 3 to 8930
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   방류구       8928 non-null   object
#  1   측정일자      8928 non-null   object
#  2   측정시간      8928 non-null   object
#  3   COD_기준치   8928 non-null   object
#  4   COD_측정치   8928 non-null   float64
#  5   COD_상태정보  8928 non-null   object
#  6   SS_기준치    8928 non-null   object
#  7   SS_측정치    8928 non-null   float64
#  8   SS_상태정보   8928 non-null   object
#  9   T-N_기준치   8928 non-null   object
#  10  T-N_측정치   8928 non-null   float64
#  11  T-N_상태정보  8928 non-null   object
#  12  T-P_기준치   8928 non-null   object
#  13  T-P_측정치   8928 non-null   float64
#  14  T-P_상태정보  8928 non-null   object
#  15  pH_기준치    8928 non-null   object
#  16  PH_측정치    8928 non-null   object
#  17  PH_상태정보   8928 non-null   object
# dtypes: float64(4), object(14)
# memory usage: 1.3+ MB

# %%
data = data.astype({'PH_측정치':float})

# %%
data_cod_error = data[data['COD_상태정보'] != '장비정상']
data_cod_good = data[data['COD_상태정보'] == '장비정상']

# %%
data_cod_error['COD_측정치'].mean()
# Out:
# 19.333512064343168

# %%
data_cod_good['COD_측정치'].mean()
# Out:
# 78.33567504383402

# %%
data_ss_error = data[data['SS_상태정보'] != '장비정상']
data_ss_good = data[data['SS_상태정보'] == '장비정상']

data_tn_error = data[data['T-N_상태정보'] != '장비정상']
data_tn_good = data[data['T-N_상태정보'] == '장비정상']

data_tp_error = data[data['T-P_상태정보'] != '장비정상']
data_tp_good = data[data['T-P_상태정보'] == '장비정상']

# %%
data_ph_error = data[data['PH_상태정보'] != '장비정상']
data_ph_good = data[data['PH_상태정보'] == '장비정상']

# %%
data_ss_error['SS_측정치'].mean()
# Out:
# 8.29824120603015

# %%
data_ss_good['SS_측정치'].mean()
# Out:
# 6.294032825322391

# %%
data_tn_error['T-N_측정치'].mean()
# Out:
# 2.220279569892473

# %%
data_tn_good['T-N_측정치'].mean()
# Out:
# 15.810960616660187

# %%
data_tp_error['T-P_측정치'].mean()
# Out:
# 0.3327876344086022

# %%
data_tp_good['T-P_측정치'].mean()
# Out:
# 0.19326145395044414

# %%
data_ph_error['PH_측정치'].mean()
# Out:
# 6.997236180904524

# %%
data_ph_good['PH_측정치'].mean()
# Out:
# 6.905791324736225
